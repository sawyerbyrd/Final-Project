# %% [markdown]
# Final Project:
#
# Analysis of Rent Prices vs Income Over Time

# %%
import numpy as np
import pandas as pd

# %%
raw_data = pd.read_csv('Metro_zori_uc_sfrcondomfr_sm_month.csv')
raw_data.head()
# Out:
#    RegionID  SizeRank       RegionName RegionType StateName   2015-01-31  \
# 0    102001         0    United States    country       NaN  1232.070120
# 1    394913         1     New York, NY        msa        NY  2332.141887
# 2    753899         2  Los Angeles, CA        msa        CA  1832.730335
# 3    394463         3      Chicago, IL        msa        IL  1451.965010
# 4    394514         4       Dallas, TX        msa        TX  1113.846731
#
#     2015-02-28   2015-03-31   2015-04-30   2015-05-31  ...   2023-07-31  \
# 0  1238.758734  1247.810823  1257.662981  1267.346364  ...  1963.833747
# 1  2348.102164  2366.118116  2388.504889  2404.452697  ...  3251.098776
# 2  1845.170028  1860.490896  1873.738622  1888.148212  ...  2885.975568
# 3  1459.660786  1470.951419  1480.917264  1492.148093  ...  2018.298817
# 4  1119.502230  1127.661537  1138.614407  1148.625088  ...  1792.482691
#
#     2023-08-31   2023-09-30   2023-10-31   2023-11-30   2023-12-31  \
# ...
